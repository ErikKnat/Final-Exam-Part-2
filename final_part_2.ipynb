# %%
import pandas as pd, numpy as np
from pathlib import Path
import fsspec

S3_STATIONS_TXT   = "s3://noaa-ghcn-pds/ghcnd-stations.txt"
S3_INVENTORY_TXT  = "s3://noaa-ghcn-pds/ghcnd-inventory.txt"
S3_BY_STATION     = "s3://noaa-ghcn-pds/csv/by_station/{id}.csv"
STOR = {"anon": True}

OUTDIR = Path('../data'); OUTDIR.mkdir(parents=True, exist_ok=True)
OUT_PARQUET = OUTDIR / 'ghcn_il_top4_daily.parquet'
OUT_CSV = OUTDIR / 'ghcn_il_top4_daily.csv'
print('Output:', OUT_PARQUET.resolve())
# Out:
# Output: /home/ek33/ATMS523/ATMS-523-Module-3-pandas-datetime-climate/data/ghcn_il_top4_daily.parquet

# %%
colspecs = [(0,11),(12,20),(21,30),(31,37),(38,40),(41,71),(72,75),(76,79),(80,85)]
names = ['ID','LATITUDE','LONGITUDE','ELEVATION','STATE','NAME','GSN_FLAG','HCN_CRN_FLAG','WMO_ID']

stations = pd.read_fwf(S3_STATIONS_TXT, colspecs=colspecs, names=names, dtype={'ID':str,'STATE':str,'WMO_ID':str}, storage_options=STOR)
stations['NAME'] = stations['NAME'].str.strip(); stations['STATE'] = stations['STATE'].fillna('').str.strip()

inventory = pd.read_csv(
    S3_INVENTORY_TXT, sep=r'\s+', names=['ID','LAT','LON','ELEMENT','FIRSTYEAR','LASTYEAR'],
    dtype={'ID':str,'ELEMENT':str,'FIRSTYEAR':int,'LASTYEAR':int}, engine='python', storage_options=STOR
)

stations.head(), inventory.head()
# Out:
# (            ID  LATITUDE  LONGITUDE  ELEVATION STATE                   NAME  \
#  0  ACW00011604   17.1167   -61.7833       10.1        ST JOHNS COOLIDGE FLD
#  1  ACW00011647   17.1333   -61.7833       19.2                     ST JOHNS
#  2  AE000041196   25.3330    55.5170       34.0          SHARJAH INTER. AIRP
#  3  AEM00041194   25.2550    55.3640       10.4                   DUBAI INTL
#  4  AEM00041217   24.4330    54.6510       26.8               ABU DHABI INTL
#
#    GSN_FLAG HCN_CRN_FLAG WMO_ID
#  0      NaN          NaN    NaN
#  1      NaN          NaN    NaN
#  2      GSN          NaN  41196
#  3      NaN          NaN  41194
#  4      NaN          NaN  41217  ,
#              ID      LAT      LON ELEMENT  FIRSTYEAR  LASTYEAR
#  0  ACW00011604  17.1167 -61.7833    TMAX       1949      1949
#  1  ACW00011604  17.1167 -61.7833    TMIN       1949      1949
#  2  ACW00011604  17.1167 -61.7833    PRCP       1949      1949
#  3  ACW00011604  17.1167 -61.7833    SNOW       1949      1949
#  4  ACW00011604  17.1167 -61.7833    SNWD       1949      1949)

# %%
df = pd.read_csv(
...      "s3://noaa-ghcn-pds/csv/by_station/USC00087205.csv",
...      storage_options={"anon": True},  # passed to `s3fs.S3FileSystem`
         dtype={'Q_FLAG': 'object', 'M_FLAG': 'object'},
         parse_dates=['DATE']
... ).set_index('DATE')
# Out:
# /tmp/ipykernel_33360/2031015204.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df
# Out:
#                      ID ELEMENT  DATA_VALUE M_FLAG Q_FLAG S_FLAG  OBS_TIME
# DATE
# 1892-09-01  USC00087205    TMAX         322    NaN    NaN      6       NaN
# 1892-09-02  USC00087205    TMAX         317    NaN    NaN      6       NaN
# 1892-09-03  USC00087205    TMAX         317    NaN    NaN      6       NaN
# 1892-09-04  USC00087205    TMAX         322    NaN    NaN      6       NaN
# 1892-09-05  USC00087205    TMAX         333    NaN    NaN      6       NaN
# ...                 ...     ...         ...    ...    ...    ...       ...
# 2025-12-05  USC00087205    PRCP           0    NaN    NaN      H    1600.0
# 2025-12-06  USC00087205    PRCP           0    NaN    NaN      H    1600.0
# 2025-12-07  USC00087205    PRCP         185    NaN    NaN      H    1600.0
# 2025-12-08  USC00087205    PRCP         406    NaN    NaN      H    1600.0
# 2025-12-09  USC00087205    PRCP           3    NaN    NaN      H    1600.0
#
# [224227 rows x 7 columns]

# %%
df_t = df.copy()

# %%
#make date the index
df_t.index = pd.to_datetime(df_t.index)

# %%
df_t
# Out:
#                      ID ELEMENT  DATA_VALUE M_FLAG Q_FLAG S_FLAG  OBS_TIME
# DATE
# 1892-09-01  USC00087205    TMAX         322    NaN    NaN      6       NaN
# 1892-09-02  USC00087205    TMAX         317    NaN    NaN      6       NaN
# 1892-09-03  USC00087205    TMAX         317    NaN    NaN      6       NaN
# 1892-09-04  USC00087205    TMAX         322    NaN    NaN      6       NaN
# 1892-09-05  USC00087205    TMAX         333    NaN    NaN      6       NaN
# ...                 ...     ...         ...    ...    ...    ...       ...
# 2025-12-05  USC00087205    PRCP           0    NaN    NaN      H    1600.0
# 2025-12-06  USC00087205    PRCP           0    NaN    NaN      H    1600.0
# 2025-12-07  USC00087205    PRCP         185    NaN    NaN      H    1600.0
# 2025-12-08  USC00087205    PRCP         406    NaN    NaN      H    1600.0
# 2025-12-09  USC00087205    PRCP           3    NaN    NaN      H    1600.0
#
# [224227 rows x 7 columns]

# %%
df_recent = df_t.sort_index()
df_recent = df_recent.loc["1990-01-01":"2020-02-01"]
df_recent
# Out:
#                      ID ELEMENT  DATA_VALUE M_FLAG Q_FLAG S_FLAG  OBS_TIME
# DATE
# 1990-01-01  USC00087205    TMAX         256    NaN    NaN      0    1800.0
# 1990-01-01  USC00087205    PRCP           0    NaN    NaN      0    1800.0
# 1990-01-01  USC00087205    SNWD           0    NaN    NaN      0       NaN
# 1990-01-01  USC00087205    TOBS         167    NaN    NaN      0    1800.0
# 1990-01-01  USC00087205    SNOW           0      P    NaN      0       NaN
# ...                 ...     ...         ...    ...    ...    ...       ...
# 2020-01-31  USC00087205    PRCP           0    NaN    NaN      7    1600.0
# 2020-02-01  USC00087205    TMIN         156    NaN    NaN      7    1600.0
# 2020-02-01  USC00087205    PRCP          61    NaN    NaN      7    1600.0
# 2020-02-01  USC00087205    TOBS         183    NaN    NaN      7    1600.0
# 2020-02-01  USC00087205    TMAX         200    NaN    NaN      7    1600.0
#
# [58653 rows x 7 columns]

# %%
data = df_recent[df_recent['ELEMENT'] == 'TMIN']
data
# Out:
#                      ID ELEMENT  DATA_VALUE M_FLAG Q_FLAG S_FLAG  OBS_TIME
# DATE
# 1990-01-01  USC00087205    TMIN         144    NaN    NaN      0    1800.0
# 1990-01-02  USC00087205    TMIN          61    NaN    NaN      0    1800.0
# 1990-01-03  USC00087205    TMIN         106    NaN    NaN      0    1800.0
# 1990-01-04  USC00087205    TMIN         128    NaN    NaN      0    1800.0
# 1990-01-05  USC00087205    TMIN         189    NaN    NaN      0    1800.0
# ...                 ...     ...         ...    ...    ...    ...       ...
# 2020-01-28  USC00087205    TMIN         117    NaN    NaN      7    1600.0
# 2020-01-29  USC00087205    TMIN          83    NaN    NaN      7    1600.0
# 2020-01-30  USC00087205    TMIN         106    NaN    NaN      7    1600.0
# 2020-01-31  USC00087205    TMIN         133    NaN    NaN      7    1600.0
# 2020-02-01  USC00087205    TMIN         156    NaN    NaN      7    1600.0
#
# [10709 rows x 7 columns]

# %%
data['DATA_VALUE'] = data['DATA_VALUE']/10
data
# Out:
# /tmp/ipykernel_33360/2598556021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DATA_VALUE'] = data['DATA_VALUE']/10
#                      ID ELEMENT  DATA_VALUE M_FLAG Q_FLAG S_FLAG  OBS_TIME
# DATE
# 1990-01-01  USC00087205    TMIN        14.4    NaN    NaN      0    1800.0
# 1990-01-02  USC00087205    TMIN         6.1    NaN    NaN      0    1800.0
# 1990-01-03  USC00087205    TMIN        10.6    NaN    NaN      0    1800.0
# 1990-01-04  USC00087205    TMIN        12.8    NaN    NaN      0    1800.0
# 1990-01-05  USC00087205    TMIN        18.9    NaN    NaN      0    1800.0
# ...                 ...     ...         ...    ...    ...    ...       ...
# 2020-01-28  USC00087205    TMIN        11.7    NaN    NaN      7    1600.0
# 2020-01-29  USC00087205    TMIN         8.3    NaN    NaN      7    1600.0
# 2020-01-30  USC00087205    TMIN        10.6    NaN    NaN      7    1600.0
# 2020-01-31  USC00087205    TMIN        13.3    NaN    NaN      7    1600.0
# 2020-02-01  USC00087205    TMIN        15.6    NaN    NaN      7    1600.0
#
# [10709 rows x 7 columns]

# %%
months = [1,10,11,12]

filtered_data = data[
    (data.index.month.isin(months))]

# %%
filtered_data
# Out:
#                      ID ELEMENT  DATA_VALUE M_FLAG Q_FLAG S_FLAG  OBS_TIME
# DATE
# 1990-01-01  USC00087205    TMIN        14.4    NaN    NaN      0    1800.0
# 1990-01-02  USC00087205    TMIN         6.1    NaN    NaN      0    1800.0
# 1990-01-03  USC00087205    TMIN        10.6    NaN    NaN      0    1800.0
# 1990-01-04  USC00087205    TMIN        12.8    NaN    NaN      0    1800.0
# 1990-01-05  USC00087205    TMIN        18.9    NaN    NaN      0    1800.0
# ...                 ...     ...         ...    ...    ...    ...       ...
# 2020-01-27  USC00087205    TMIN        12.2    NaN    NaN      7    1600.0
# 2020-01-28  USC00087205    TMIN        11.7    NaN    NaN      7    1600.0
# 2020-01-29  USC00087205    TMIN         8.3    NaN    NaN      7    1600.0
# 2020-01-30  USC00087205    TMIN        10.6    NaN    NaN      7    1600.0
# 2020-01-31  USC00087205    TMIN        13.3    NaN    NaN      7    1600.0
#
# [3648 rows x 7 columns]

# %%
# Convert to fahrenheit
filtered_data['TempF'] = filtered_data['DATA_VALUE']*1.8+32
filtered_data['TempF']
# Out:
# /tmp/ipykernel_33360/3998422993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['TempF'] = filtered_data['DATA_VALUE']*1.8+32
# DATE
# 1990-01-01    57.92
# 1990-01-02    42.98
# 1990-01-03    51.08
# 1990-01-04    55.04
# 1990-01-05    66.02
#               ...
# 2020-01-27    53.96
# 2020-01-28    53.06
# 2020-01-29    46.94
# 2020-01-30    51.08
# 2020-01-31    55.94
# Name: TempF, Length: 3648, dtype: float64

# %%
# Attempting to interpret what "mean number of days per month" signifies

# Frost Risk
frost = filtered_data[filtered_data['TempF']<= 32]
frost
# Out:
#                      ID ELEMENT  DATA_VALUE M_FLAG Q_FLAG S_FLAG  OBS_TIME  \
# DATE
# 1992-01-17  USC00087205    TMIN        -2.2    NaN    NaN      0    1800.0
# 1992-01-21  USC00087205    TMIN         0.0    NaN    NaN      0    1800.0
# 1992-01-25  USC00087205    TMIN         0.0    NaN    NaN      0    1800.0
# 1993-12-27  USC00087205    TMIN        -1.1    NaN    NaN      0    1600.0
# 1995-12-11  USC00087205    TMIN         0.0    NaN    NaN      0    1600.0
# ...                 ...     ...         ...    ...    ...    ...       ...
# 2018-01-04  USC00087205    TMIN        -2.8    NaN    NaN      7    1600.0
# 2018-01-05  USC00087205    TMIN        -1.7    NaN    NaN      7    1600.0
# 2018-01-18  USC00087205    TMIN        -5.6    NaN    NaN      7    1600.0
# 2018-01-19  USC00087205    TMIN         0.0    NaN    NaN      7    1600.0
# 2020-01-22  USC00087205    TMIN        -1.1    NaN    NaN      7    1600.0
#
#             TempF
# DATE
# 1992-01-17  28.04
# 1992-01-21  32.00
# 1992-01-25  32.00
# 1993-12-27  30.02
# 1995-12-11  32.00
# ...           ...
# 2018-01-04  26.96
# 2018-01-05  28.94
# 2018-01-18  21.92
# 2018-01-19  32.00
# 2020-01-22  30.02
#
# [75 rows x 8 columns]

# %%
print(len(frost))
# Out:
# 75

# %%
print(len(filtered_data))
# Out:
# 3648

# %%
# Freeze Risk
freeze = filtered_data[filtered_data['TempF']<= 28]
freeze
# Out:
#                      ID ELEMENT  DATA_VALUE M_FLAG Q_FLAG S_FLAG  OBS_TIME  \
# DATE
# 1995-12-25  USC00087205    TMIN        -3.3    NaN    NaN      0    1600.0
# 1995-12-26  USC00087205    TMIN        -3.3    NaN    NaN      0    1600.0
# 1995-12-27  USC00087205    TMIN        -7.8    NaN    NaN      0    1600.0
# 1997-01-19  USC00087205    TMIN        -3.9    NaN    NaN      0    1600.0
# 1999-01-06  USC00087205    TMIN        -2.8    NaN    NaN      0    1600.0
# 1999-01-07  USC00087205    TMIN        -2.8    NaN    NaN      0    1600.0
# 1999-01-08  USC00087205    TMIN        -3.3    NaN    NaN      0    1600.0
# 2001-01-01  USC00087205    TMIN        -3.3    NaN    NaN      0    1600.0
# 2003-01-24  USC00087205    TMIN        -3.3    NaN    NaN      0    1600.0
# 2008-01-03  USC00087205    TMIN        -2.8    NaN    NaN      0    1600.0
# 2009-01-22  USC00087205    TMIN        -3.3    NaN    NaN      0    1600.0
# 2010-01-06  USC00087205    TMIN        -2.8    NaN    NaN      0    1600.0
# 2010-01-07  USC00087205    TMIN        -2.8    NaN    NaN      0    1600.0
# 2010-01-10  USC00087205    TMIN        -3.3    NaN    NaN      0    1600.0
# 2010-01-11  USC00087205    TMIN        -5.0    NaN    NaN      0    1600.0
# 2010-12-28  USC00087205    TMIN        -3.3    NaN    NaN      0    1600.0
# 2010-12-29  USC00087205    TMIN        -3.3    NaN    NaN      0    1600.0
# 2014-01-25  USC00087205    TMIN        -3.3    NaN    NaN      7    1600.0
# 2018-01-04  USC00087205    TMIN        -2.8    NaN    NaN      7    1600.0
# 2018-01-18  USC00087205    TMIN        -5.6    NaN    NaN      7    1600.0
#
#             TempF
# DATE
# 1995-12-25  26.06
# 1995-12-26  26.06
# 1995-12-27  17.96
# 1997-01-19  24.98
# 1999-01-06  26.96
# 1999-01-07  26.96
# 1999-01-08  26.06
# 2001-01-01  26.06
# 2003-01-24  26.06
# 2008-01-03  26.96
# 2009-01-22  26.06
# 2010-01-06  26.96
# 2010-01-07  26.96
# 2010-01-10  26.06
# 2010-01-11  23.00
# 2010-12-28  26.06
# 2010-12-29  26.06
# 2014-01-25  26.06
# 2018-01-04  26.96
# 2018-01-18  21.92

# %%
print(len(freeze))
# Out:
# 20

# %%
# Get a count of the days and divide by number of years to get average amount
frost['count'] = frost['TempF']/frost['TempF']
frost['count']
# Out:
# /tmp/ipykernel_33360/3096402112.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frost['count'] = frost['TempF']/frost['TempF']
# DATE
# 1992-01-17    1.0
# 1992-01-21    1.0
# 1992-01-25    1.0
# 1993-12-27    1.0
# 1995-12-11    1.0
#              ...
# 2018-01-04    1.0
# 2018-01-05    1.0
# 2018-01-18    1.0
# 2018-01-19    1.0
# 2020-01-22    1.0
# Name: count, Length: 75, dtype: float64

# %%
# and divide by number of years to get average amount
frost['count'] = frost['count']/30
frost['count']
# Out:
# /tmp/ipykernel_33360/3231695258.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frost['count'] = frost['count']/30
# DATE
# 1992-01-17    0.033333
# 1992-01-21    0.033333
# 1992-01-25    0.033333
# 1993-12-27    0.033333
# 1995-12-11    0.033333
#                 ...
# 2018-01-04    0.033333
# 2018-01-05    0.033333
# 2018-01-18    0.033333
# 2018-01-19    0.033333
# 2020-01-22    0.033333
# Name: count, Length: 75, dtype: float64

# %%
frost_risk = frost.groupby([frost.index.month])["count"].sum()

# %%
frost_risk
# Out:
# DATE
# 1     1.866667
# 11    0.033333
# 12    0.600000
# Name: count, dtype: float64

# %%
# Freeze Risk
freeze['count'] = freeze['TempF']/freeze['TempF']
freeze['count'] = freeze['count']/30
freeze['count']
# Out:
# /tmp/ipykernel_33360/98458811.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   freeze['count'] = freeze['TempF']/freeze['TempF']
# /tmp/ipykernel_33360/98458811.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   freeze['count'] = freeze['count']/30
# DATE
# 1995-12-25    0.033333
# 1995-12-26    0.033333
# 1995-12-27    0.033333
# 1997-01-19    0.033333
# 1999-01-06    0.033333
# 1999-01-07    0.033333
# 1999-01-08    0.033333
# 2001-01-01    0.033333
# 2003-01-24    0.033333
# 2008-01-03    0.033333
# 2009-01-22    0.033333
# 2010-01-06    0.033333
# 2010-01-07    0.033333
# 2010-01-10    0.033333
# 2010-01-11    0.033333
# 2010-12-28    0.033333
# 2010-12-29    0.033333
# 2014-01-25    0.033333
# 2018-01-04    0.033333
# 2018-01-18    0.033333
# Name: count, dtype: float64

# %%
freeze_risk = freeze.groupby([freeze.index.month])["count"].sum()
freeze_risk
# Out:
# DATE
# 1     0.500000
# 12    0.166667
# Name: count, dtype: float64

# %%
# Correlations with ENSO

# Import ENSO
enso = pd.read_csv('https://www.cpc.ncep.noaa.gov/data/indices/sstoi.indices', delim_whitespace=True)
enso
# Out:
# /tmp/ipykernel_33360/1586653918.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   enso = pd.read_csv('https://www.cpc.ncep.noaa.gov/data/indices/sstoi.indices', delim_whitespace=True)
#        YR  MON  NINO1+2  ANOM  NINO3  ANOM.1  NINO4  ANOM.2  NINO3.4  ANOM.3
# 0    1982    1    24.28 -0.24  25.84    0.17  28.01   -0.21    26.65    0.08
# 1    1982    2    25.38 -0.72  26.26   -0.11  27.99   -0.11    26.54   -0.20
# 2    1982    3    25.22 -1.38  26.92   -0.25  28.18   -0.05    27.09   -0.14
# 3    1982    4    24.57 -1.16  27.52   -0.05  28.61    0.10    27.83    0.02
# 4    1982    5    24.00 -0.62  27.70    0.49  29.19    0.40    28.37    0.49
# ..    ...  ...      ...   ...    ...     ...    ...     ...      ...     ...
# 522  2025    7    22.29  0.46  25.92    0.04  28.84    0.05    27.24   -0.06
# 523  2025    8    21.09  0.23  24.97   -0.24  28.63   -0.06    26.58   -0.33
# 524  2025    9    20.40 -0.18  24.60   -0.41  28.41   -0.27    26.32   -0.44
# 525  2025   10    20.83 -0.04  24.74   -0.35  28.36   -0.33    26.29   -0.48
# 526  2025   11    21.28 -0.34  24.60   -0.60  28.15   -0.52    26.14   -0.68
#
# [527 rows x 10 columns]

# %%
enso['MON']
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 522     7
# 523     8
# 524     9
# 525    10
# 526    11
# Name: MON, Length: 527, dtype: int64

# %%
enso['month'] = enso['MON']
enso['year'] = enso['YR']
enso['day'] = 1
enso
# Out:
#        YR  MON  NINO1+2  ANOM  NINO3  ANOM.1  NINO4  ANOM.2  NINO3.4  ANOM.3  \
# 0    1982    1    24.28 -0.24  25.84    0.17  28.01   -0.21    26.65    0.08
# 1    1982    2    25.38 -0.72  26.26   -0.11  27.99   -0.11    26.54   -0.20
# 2    1982    3    25.22 -1.38  26.92   -0.25  28.18   -0.05    27.09   -0.14
# 3    1982    4    24.57 -1.16  27.52   -0.05  28.61    0.10    27.83    0.02
# 4    1982    5    24.00 -0.62  27.70    0.49  29.19    0.40    28.37    0.49
# ..    ...  ...      ...   ...    ...     ...    ...     ...      ...     ...
# 522  2025    7    22.29  0.46  25.92    0.04  28.84    0.05    27.24   -0.06
# 523  2025    8    21.09  0.23  24.97   -0.24  28.63   -0.06    26.58   -0.33
# 524  2025    9    20.40 -0.18  24.60   -0.41  28.41   -0.27    26.32   -0.44
# 525  2025   10    20.83 -0.04  24.74   -0.35  28.36   -0.33    26.29   -0.48
# 526  2025   11    21.28 -0.34  24.60   -0.60  28.15   -0.52    26.14   -0.68
#
#      month  year  day
# 0        1  1982    1
# 1        2  1982    1
# 2        3  1982    1
# 3        4  1982    1
# 4        5  1982    1
# ..     ...   ...  ...
# 522      7  2025    1
# 523      8  2025    1
# 524      9  2025    1
# 525     10  2025    1
# 526     11  2025    1
#
# [527 rows x 13 columns]

# %%
enso['date'] = pd.to_datetime(enso[['year', 'month', 'day']])
enso
# Out:
#        YR  MON  NINO1+2  ANOM  NINO3  ANOM.1  NINO4  ANOM.2  NINO3.4  ANOM.3  \
# 0    1982    1    24.28 -0.24  25.84    0.17  28.01   -0.21    26.65    0.08
# 1    1982    2    25.38 -0.72  26.26   -0.11  27.99   -0.11    26.54   -0.20
# 2    1982    3    25.22 -1.38  26.92   -0.25  28.18   -0.05    27.09   -0.14
# 3    1982    4    24.57 -1.16  27.52   -0.05  28.61    0.10    27.83    0.02
# 4    1982    5    24.00 -0.62  27.70    0.49  29.19    0.40    28.37    0.49
# ..    ...  ...      ...   ...    ...     ...    ...     ...      ...     ...
# 522  2025    7    22.29  0.46  25.92    0.04  28.84    0.05    27.24   -0.06
# 523  2025    8    21.09  0.23  24.97   -0.24  28.63   -0.06    26.58   -0.33
# 524  2025    9    20.40 -0.18  24.60   -0.41  28.41   -0.27    26.32   -0.44
# 525  2025   10    20.83 -0.04  24.74   -0.35  28.36   -0.33    26.29   -0.48
# 526  2025   11    21.28 -0.34  24.60   -0.60  28.15   -0.52    26.14   -0.68
#
#      month  year  day       date
# 0        1  1982    1 1982-01-01
# 1        2  1982    1 1982-02-01
# 2        3  1982    1 1982-03-01
# 3        4  1982    1 1982-04-01
# 4        5  1982    1 1982-05-01
# ..     ...   ...  ...        ...
# 522      7  2025    1 2025-07-01
# 523      8  2025    1 2025-08-01
# 524      9  2025    1 2025-09-01
# 525     10  2025    1 2025-10-01
# 526     11  2025    1 2025-11-01
#
# [527 rows x 14 columns]

# %%
enso.set_index('date', inplace = True)
enso
# Out:
#               YR  MON  NINO1+2  ANOM  NINO3  ANOM.1  NINO4  ANOM.2  NINO3.4  \
# date
# 1982-01-01  1982    1    24.28 -0.24  25.84    0.17  28.01   -0.21    26.65
# 1982-02-01  1982    2    25.38 -0.72  26.26   -0.11  27.99   -0.11    26.54
# 1982-03-01  1982    3    25.22 -1.38  26.92   -0.25  28.18   -0.05    27.09
# 1982-04-01  1982    4    24.57 -1.16  27.52   -0.05  28.61    0.10    27.83
# 1982-05-01  1982    5    24.00 -0.62  27.70    0.49  29.19    0.40    28.37
# ...          ...  ...      ...   ...    ...     ...    ...     ...      ...
# 2025-07-01  2025    7    22.29  0.46  25.92    0.04  28.84    0.05    27.24
# 2025-08-01  2025    8    21.09  0.23  24.97   -0.24  28.63   -0.06    26.58
# 2025-09-01  2025    9    20.40 -0.18  24.60   -0.41  28.41   -0.27    26.32
# 2025-10-01  2025   10    20.83 -0.04  24.74   -0.35  28.36   -0.33    26.29
# 2025-11-01  2025   11    21.28 -0.34  24.60   -0.60  28.15   -0.52    26.14
#
#             ANOM.3  month  year  day
# date
# 1982-01-01    0.08      1  1982    1
# 1982-02-01   -0.20      2  1982    1
# 1982-03-01   -0.14      3  1982    1
# 1982-04-01    0.02      4  1982    1
# 1982-05-01    0.49      5  1982    1
# ...            ...    ...   ...  ...
# 2025-07-01   -0.06      7  2025    1
# 2025-08-01   -0.33      8  2025    1
# 2025-09-01   -0.44      9  2025    1
# 2025-10-01   -0.48     10  2025    1
# 2025-11-01   -0.68     11  2025    1
#
# [527 rows x 13 columns]

# %%
filtered_new = filtered_data.copy()
filtered_temp = filtered_new['TempF']
filtered_temp = filtered_temp.resample('1M').mean()
filtered_temp
# Out:
# /tmp/ipykernel_33360/600788537.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   filtered_temp = filtered_temp.resample('1M').mean()
# DATE
# 1990-01-31    54.801935
# 1990-02-28          NaN
# 1990-03-31          NaN
# 1990-04-30          NaN
# 1990-05-31          NaN
#                 ...
# 2019-09-30          NaN
# 2019-10-31    71.989032
# 2019-11-30    58.851034
# 2019-12-31    59.338400
# 2020-01-31    54.430323
# Freq: ME, Name: TempF, Length: 361, dtype: float64

# %%
filtered_temp = filtered_temp.dropna()
filtered_temp.index = filtered_temp.index.map(lambda d: d.replace(day=1))
filtered_temp
# Out:
# DATE
# 1990-01-01    54.801935
# 1990-10-01    66.606452
# 1990-11-01    57.362000
# 1990-12-01    53.460645
# 1991-01-01    57.316129
#                 ...
# 2019-01-01    49.001290
# 2019-10-01    71.989032
# 2019-11-01    58.851034
# 2019-12-01    59.338400
# 2020-01-01    54.430323
# Name: TempF, Length: 121, dtype: float64

# %%
merged = pd.merge(filtered_temp, enso, left_index=True, right_index=True)
merged
# Out:
#                 TempF    YR  MON  NINO1+2  ANOM  NINO3  ANOM.1  NINO4  ANOM.2  \
# 1990-01-01  54.801935  1990    1    23.92 -0.60  25.27   -0.40  28.20   -0.02
# 1990-10-01  66.606452  1990   10    20.08 -0.79  24.91   -0.17  28.96    0.28
# 1990-11-01  57.362000  1990   11    20.73 -0.90  24.84   -0.36  28.82    0.15
# 1990-12-01  53.460645  1990   12    22.12 -0.72  25.18   -0.08  28.84    0.39
# 1991-01-01  57.316129  1991    1    23.73 -0.78  25.63   -0.05  28.62    0.40
# ...               ...   ...  ...      ...   ...    ...     ...    ...     ...
# 2019-01-01  49.001290  2019    1    25.32  0.80  26.41    0.73  29.06    0.83
# 2019-10-01  71.989032  2019   10    19.94 -0.93  25.25    0.16  29.53    0.84
# 2019-11-01  58.851034  2019   11    21.49 -0.13  25.57    0.37  29.40    0.73
# 2019-12-01  59.338400  2019   12    23.11  0.27  25.56    0.29  29.29    0.85
# 2020-01-01  54.430323  2020    1    24.49 -0.03  25.89    0.22  29.16    0.94
#
#             NINO3.4  ANOM.3  month  year  day
# 1990-01-01    26.45   -0.11      1  1990    1
# 1990-10-01    26.95    0.18     10  1990    1
# 1990-11-01    26.73   -0.09     11  1990    1
# 1990-12-01    26.86    0.22     12  1990    1
# 1991-01-01    26.89    0.33      1  1991    1
# ...             ...     ...    ...   ...  ...
# 2019-01-01    27.24    0.67      1  2019    1
# 2019-10-01    27.28    0.52     10  2019    1
# 2019-11-01    27.28    0.46     11  2019    1
# 2019-12-01    27.08    0.44     12  2019    1
# 2020-01-01    27.08    0.52      1  2020    1
#
# [121 rows x 14 columns]

# %%
numeric_df = merged[['TempF','ANOM','ANOM.1','ANOM.2','ANOM.3']]
numeric_df
# Out:
#                 TempF  ANOM  ANOM.1  ANOM.2  ANOM.3
# 1990-01-01  54.801935 -0.60   -0.40   -0.02   -0.11
# 1990-10-01  66.606452 -0.79   -0.17    0.28    0.18
# 1990-11-01  57.362000 -0.90   -0.36    0.15   -0.09
# 1990-12-01  53.460645 -0.72   -0.08    0.39    0.22
# 1991-01-01  57.316129 -0.78   -0.05    0.40    0.33
# ...               ...   ...     ...     ...     ...
# 2019-01-01  49.001290  0.80    0.73    0.83    0.67
# 2019-10-01  71.989032 -0.93    0.16    0.84    0.52
# 2019-11-01  58.851034 -0.13    0.37    0.73    0.46
# 2019-12-01  59.338400  0.27    0.29    0.85    0.44
# 2020-01-01  54.430323 -0.03    0.22    0.94    0.52
#
# [121 rows x 5 columns]

# %%
# Correlations
corr_matrix = numeric_df.corr(method='pearson')
# Compute R² by squaring correlation coefficients
r_squared_matrix = corr_matrix ** 2

# Print results
print("Correlation matrix (Pearson):")
print(corr_matrix, "\n")

print("R² matrix (Coefficient of Determination):")
print(r_squared_matrix)
# Out:
# Correlation matrix (Pearson):
#            TempF      ANOM    ANOM.1    ANOM.2    ANOM.3
# TempF   1.000000  0.076600  0.108143  0.143696  0.122766
# ANOM    0.076600  1.000000  0.865486  0.529156  0.744179
# ANOM.1  0.108143  0.865486  1.000000  0.798120  0.962156
# ANOM.2  0.143696  0.529156  0.798120  1.000000  0.906447
# ANOM.3  0.122766  0.744179  0.962156  0.906447  1.000000
#
# R² matrix (Coefficient of Determination):
#            TempF      ANOM    ANOM.1    ANOM.2    ANOM.3
# TempF   1.000000  0.005868  0.011695  0.020649  0.015071
# ANOM    0.005868  1.000000  0.749066  0.280006  0.553802
# ANOM.1  0.011695  0.749066  1.000000  0.636995  0.925743
# ANOM.2  0.020649  0.280006  0.636995  1.000000  0.821646
# ANOM.3  0.015071  0.553802  0.925743  0.821646  1.000000

# %% [markdown]
# The highest correlation with the temperatures is: ANOM.2

# %%
merged2 = pd.merge(frost_new, enso, left_index=True, right_index=True)
merged2
# Out:
#                      ID ELEMENT  DATA_VALUE M_FLAG Q_FLAG S_FLAG  OBS_TIME  \
# 1992-01-01  USC00087205    TMIN        -2.2    NaN    NaN      0    1800.0
# 1992-01-01  USC00087205    TMIN         0.0    NaN    NaN      0    1800.0
# 1992-01-01  USC00087205    TMIN         0.0    NaN    NaN      0    1800.0
# 1993-12-01  USC00087205    TMIN        -1.1    NaN    NaN      0    1600.0
# 1995-12-01  USC00087205    TMIN         0.0    NaN    NaN      0    1600.0
# ...                 ...     ...         ...    ...    ...    ...       ...
# 2018-01-01  USC00087205    TMIN        -2.8    NaN    NaN      7    1600.0
# 2018-01-01  USC00087205    TMIN        -1.7    NaN    NaN      7    1600.0
# 2018-01-01  USC00087205    TMIN        -5.6    NaN    NaN      7    1600.0
# 2018-01-01  USC00087205    TMIN         0.0    NaN    NaN      7    1600.0
# 2020-01-01  USC00087205    TMIN        -1.1    NaN    NaN      7    1600.0
#
#             TempF     count    YR  ...  ANOM  NINO3  ANOM.1  NINO4  ANOM.2  \
# 1992-01-01  28.04  0.033333  1992  ...  0.07  26.86    1.18  28.80    0.58
# 1992-01-01  32.00  0.033333  1992  ...  0.07  26.86    1.18  28.80    0.58
# 1992-01-01  32.00  0.033333  1992  ...  0.07  26.86    1.18  28.80    0.58
# 1993-12-01  30.02  0.033333  1993  ... -0.37  25.25   -0.02  28.74    0.29
# 1995-12-01  32.00  0.033333  1995  ... -0.86  24.31   -0.96  27.96   -0.48
# ...           ...       ...   ...  ...   ...    ...     ...    ...     ...
# 2018-01-01  26.96  0.033333  2018  ... -0.74  24.59   -1.09  28.02   -0.20
# 2018-01-01  28.94  0.033333  2018  ... -0.74  24.59   -1.09  28.02   -0.20
# 2018-01-01  21.92  0.033333  2018  ... -0.74  24.59   -1.09  28.02   -0.20
# 2018-01-01  32.00  0.033333  2018  ... -0.74  24.59   -1.09  28.02   -0.20
# 2020-01-01  30.02  0.033333  2020  ... -0.03  25.89    0.22  29.16    0.94
#
#             NINO3.4  ANOM.3  month  year  day
# 1992-01-01    28.23    1.67      1  1992    1
# 1992-01-01    28.23    1.67      1  1992    1
# 1992-01-01    28.23    1.67      1  1992    1
# 1993-12-01    26.74    0.10     12  1993    1
# 1995-12-01    25.73   -0.91     12  1995    1
# ...             ...     ...    ...   ...  ...
# 2018-01-01    25.87   -0.70      1  2018    1
# 2018-01-01    25.87   -0.70      1  2018    1
# 2018-01-01    25.87   -0.70      1  2018    1
# 2018-01-01    25.87   -0.70      1  2018    1
# 2020-01-01    27.08    0.52      1  2020    1
#
# [75 rows x 22 columns]

# %%
numeric_df = merged2[['TempF','ANOM','ANOM.1','ANOM.2','ANOM.3']]

# Correlations
corr_matrix = numeric_df.corr(method='pearson')
# Compute R² by squaring correlation coefficients
r_squared_matrix = corr_matrix ** 2

# Print results
print("Correlation matrix (Pearson):")
print(corr_matrix, "\n")

print("R² matrix (Coefficient of Determination):")
print(r_squared_matrix)
# Out:
# Correlation matrix (Pearson):
#            TempF      ANOM    ANOM.1    ANOM.2    ANOM.3
# TempF   1.000000  0.185249  0.115522  0.019083  0.072327
# ANOM    0.185249  1.000000  0.823232  0.611319  0.700054
# ANOM.1  0.115522  0.823232  1.000000  0.831465  0.957924
# ANOM.2  0.019083  0.611319  0.831465  1.000000  0.931800
# ANOM.3  0.072327  0.700054  0.957924  0.931800  1.000000
#
# R² matrix (Coefficient of Determination):
#            TempF      ANOM    ANOM.1    ANOM.2    ANOM.3
# TempF   1.000000  0.034317  0.013345  0.000364  0.005231
# ANOM    0.034317  1.000000  0.677711  0.373710  0.490076
# ANOM.1  0.013345  0.677711  1.000000  0.691334  0.917618
# ANOM.2  0.000364  0.373710  0.691334  1.000000  0.868251
# ANOM.3  0.005231  0.490076  0.917618  0.868251  1.000000

# %% [markdown]
# The highest correlation with the frost temperatures is: ANOM
# I Know I did not do it right to finish, but I ran out of time.
